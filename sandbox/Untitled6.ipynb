# %%
import IPython.display as ipd
import numpy as np

from src.config_test import c
from src.services import get_msg_provider, get_wave_provider

wp = get_wave_provider(c)
mp = get_msg_provider(c)

wave = wp.get_audio_fragment("XC602886.ogg", range_seconds=[0, 5])
msg = mp.msg(wave.astype(np.float64))

print(msg)
# Out:
# [[-inf  inf -inf ... -inf -inf -inf]
#  [-inf  inf -inf ... -inf -inf  inf]
#  [ inf  inf -inf ... -inf -inf  inf]
#  ...
#  [-inf -inf -inf ... -inf -inf -inf]
#  [-inf -inf -inf ... -inf -inf -inf]
#  [-inf -inf -inf ... -inf -inf -inf]]

# %%
wave
# Out:
# array([ 0.006035,  0.00983 ,  0.009026, ..., -0.521   , -0.518   ,
#        -0.4365  ], dtype=float16)

# %%
ipd.Audio(data=wave, rate=32000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
s = 'a_b_c_d_e'
p = s.split('_')

# %%
a, b, *rest = p

# %%
rest
# Out:
# ['c', 'd', 'e']

# %%
class A():
    def tst(self):
        print(self.__class__.__name__)

# %%
a =A()

# %%
a.tst()
# Out:
# A
